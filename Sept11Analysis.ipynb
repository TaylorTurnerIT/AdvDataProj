# %%
# !uv pip install pandas
# Out:
# Running cells with '.venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/mnt/c/Users/Taylor/ComputerScience/AdvDataProj/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd

# %%
df = pd.read_xls('Sept11Travel.xls')
