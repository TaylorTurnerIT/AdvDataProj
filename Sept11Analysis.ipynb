# %%
# %pip install uv --quiet
# %uv pip install pandas xlrd numpy matplotlib seaborn --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_excel('Sept11Travel.xls')

# %%
df.head()
# Out:
#        Month  Air RPM (000s)    Rail PM  Car (billions)
# 0 1990-01-01        35153577  454115779      163.275384
# 1 1990-02-01        32965187  435086002      153.254409
# 2 1990-03-01        39993913  568289732      178.417577
# 3 1990-04-01        37981886  568101697      178.680686
# 4 1990-05-01        38419672  539628385      188.876171

# %%
# Summary statistics
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Month           172 non-null    datetime64[us]
#  1   Air RPM (000s)  172 non-null    int64
#  2   Rail PM         172 non-null    int64
#  3   Car (billions)  172 non-null    float64
# dtypes: datetime64[us](1), float64(1), int64(2)
# memory usage: 5.5 KB

# %%
df.describe().T
# Out:
#                 count                        mean                  min  \
# Month             172  1997-02-14 13:23:43.255814  1990-01-01 00:00:00
# Air RPM (000s)  172.0             49257805.680233           29672427.0
# Rail PM         172.0            482755766.244186          326874247.0
# Car (billions)  172.0                   210.25018           153.254409
#
#                                 25%                  50%                  75%  \
# Month           1993-07-24 06:00:00  1997-02-15 00:00:00  2000-09-08 12:00:00
# Air RPM (000s)          42655216.25           49460850.5           55361645.5
# Rail PM                 440216230.0          477074682.0         537689283.75
# Car (billions)            192.89775              209.706             229.7585
#
#                                 max              std
# Month           2004-04-01 00:00:00              NaN
# Air RPM (000s)           69003617.0   8603754.860668
# Rail PM                 664013874.0  68550402.950306
# ...

# %%
df.isnull().sum()
# Out:
# Month             0
# Air RPM (000s)    0
# Rail PM           0
# Car (billions)    0
# dtype: int64

# %%
airrpm_counts = df['Air RPM (000s)']

plt.figure(figsize=(8, 6))
plt.bar(airrpm_counts.index, airrpm_counts, color='lightblue')
plt.title('Count Plot of Air RPM')
plt.xlabel('Air RPM')
plt.ylabel('Count')
plt.show()
